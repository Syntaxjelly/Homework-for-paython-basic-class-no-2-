# %% [markdown]
# <a href="https://colab.research.google.com/github/Syntaxjelly/Homework-for-paython-basic-class-no-2-/blob/main/Homework%20class%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## H1: Write a program to perform the subtraction, multipllication and division
a=10
b=20
print(a-b)
print(a*b)
print(a/b)
# Out:
# -10
# 200
# 0.5

# %%
## H2: Write a program to declare variables for id, name, batch, and hometown, and assign values, and finally print.
Student_id = 'SM-ML-2025-B1-003'
student_name = 'Md shafwan Bin Noor'
student_batch = 'Batch 01'
Hometown = 'Noakhali'

print( Student_id,'\n',student_name,'\n',student_batch,'\n', Hometown)
# Out:
# SM-ML-2025-B1-003
#  Md shafwan Bin Noor
#  Batch 01
#  Noakhali

# %%
## H3: Write a program to change values of an integer variable
age = 20

print("Initial value of age:", age)
age = 21

print("Updated value of age:", age)
# Out:
# Initial value of age: 20
# Updated value of age: 21

# %%
#H4: Write a program to take two string numbers and convert them to integers using explicit type conversion.
x = '10'
y=20
print(type(x))
x=int(x)
sum=x+y
print(sum)
print(type(sum))
# Out:
# <class 'str'>
# 30
# <class 'int'>
